# %%
import requests
from bs4 import BeautifulSoup

URL = 'https://www.goibibo.com/flights/air-HYD-CJB-20191217--1-0-0-E-D/'
page = requests.get(URL)

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE doctype html>
#
# <html lang="en-us">
# <head>
# <script>
#           var starttime = new Date();
#         </script>
# <title data-react-helmet="true"></title>
# <meta charset="utf-8" data-react-helmet="true"/><meta content="user-scalable=no, initial-scale=1, maximum-scale=1, minimum-scale=1, width=device-width, height=device-height, target-densitydpi=device-dpi" data-react-helmet="true" name="viewport"/>
# <link href="/favicon.ico" rel="shortcut icon"/>
# <link href="https://www.goibibo.com/flights/" rel="canonical"/>
# <link href="android-app://com.goibibo/goibibo/www.goibibo.com/app/flights/" rel="alternate"/>
# <link href="//goibibo.ibcdn.com/" rel="dns-prefetch"/>
# <link href="//hermes.goibibo.com/" rel="dns-prefetch"/>
# <link href="/manifest.json" rel="manifest"/>
# <meta content="239522418693" property="fb:pages"/>
# <meta content="text/html;charset=utf-8" httpequivv="content-type"/>
# <meta content="en" httpequiv="content-language"/>
# ...
